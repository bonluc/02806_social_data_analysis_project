# %% [markdown]
# # Central Idea of project

# %% [markdown]
# **What is the Idea**:
# * To investigate patterns traffic collisions temporally, spatially in NYC. To find any groupings of data with regards to street, vehicle types, injruies/deaths
# * NYC introduce zero vision in 2014 and we want to investifate whether this has changed anything
#
# **Which datasets do you need/use to explore the data**:
# * We use nyc traffic collions data from 2013-2025
# * Link: https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95/data_preview
#
# **Why is it interesting**:
# * The investigation of traffic collision patterns can potentially help reveal structural designs that can optimized for mitigation crashes saving insurance money, mitigating injuries and most improtantly deaths.
# * With that the case is both motivated financially and ethically

# %% [markdown]
# # Mock up of the visualizations

# %% [markdown]
# # Genre of storytelling

# %% [markdown]
# **What Genre is it**:
#
#  * Annottated slide show or magazine style ( scrollytelling)?
#
# **Why is that Genre right for telling the story you want to communicate with the data**:
#
# * The data is quite dense and has a lot of potential directions.
# * To sort out the nosie we guide the reader with the findings we find interesting while leaving some room for the reader to do some exploring on their own

# %% [markdown]
# # Preliminary data-analysis

# %% [markdown]
# **What is the total size of your data? (MB, number of rows, number of variables, etc)**:
# * 2233.05 MB in size
# * 2.253.192 datapoints
# * 29 columns
#
# **What are other properties? (What is the date range? Is is it geo-data?, then a quick plot of locations, etc.)**:
# * The data contains time of day and dates ranges from 01/01/2013 to 12/31/2025
# * It contains locational data like: lonigtude, latitude coordinates, borough of accident, on/off/cross streetnames and zip codes
# * Numerical features are: Number of person/pedestrians/cyclist/motorist killed
# * Categorical features are: Contributing factor of vehicles (62 different types) and type of vehicle
#
# **Show the fundamental distributions of the data (similar to the work we did on SF crime data)**:
